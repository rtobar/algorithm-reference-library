# %% [markdown]
# ## Demonstrate full circle wide field imaging
#
# This include prediction of components, inversion, point source fitting. We will compare the output images with the input models, looking for closeness in flux and position.

# %%
% matplotlib inline

import os
import sys

sys.path.append(os.path.join('..','..'))

results_dir = './results'
os.makedirs(results_dir, exist_ok=True)

from matplotlib import pylab

pylab.rcParams['figure.figsize'] = (10.0, 10.0)
pylab.rcParams['image.cmap'] = 'rainbow'

import numpy

from astropy.coordinates import SkyCoord
from astropy.time import Time
from astropy import units as u
from astropy.wcs.utils import pixel_to_skycoord

from arl.visibility.base import create_visibility
from arl.visibility.operations import sum_visibility
from arl.visibility.iterators import vis_timeslice_iter
from arl.util.testing_support import create_named_configuration
from arl.util.timing import timing

from matplotlib import pyplot as plt

from arl.skycomponent.operations import create_skycomponent, find_skycomponents, \
    find_nearest_component, insert_skycomponent
from arl.image.operations import show_image, export_image_to_fits, qa_image, smooth_image
from arl.image.iterators import  image_raster_iter
from arl.util.testing_support import create_named_configuration
from arl.imaging import advise_wide_field, create_image_from_visibility, predict_skycomponent_visibility
from arl.imaging.imaging_context import invert_function, predict_function
from arl.data.polarisation import PolarisationFrame

import logging

log = logging.getLogger()
log.setLevel(logging.DEBUG)
log.addHandler(logging.StreamHandler(sys.stdout))

# %%
from arl import arl_default_args
from arl.data.parameters import set_parameters, get_parameter

arl_default_args('imaging-fits.ini')

# %% [markdown]
# Construct the SKA1-LOW core configuration

# %%
lowcore = create_named_configuration('LOWBD2-CORE')
# Out:
# create_configuration_from_file: Maximum radius inf m includes 166 antennas/stations

# %% [markdown]
# We create the visibility. This just makes the uvw, time, antenna1, antenna2, weight columns in a table

# %%
times = numpy.array([-3.0, -2.0, -1.0, 0.0, 1.0, 2.0, 3.0]) * (numpy.pi / 12.0)
frequency = numpy.array([1e8])
channel_bandwidth = numpy.array([1e6])
reffrequency = numpy.max(frequency)
phasecentre = SkyCoord(ra=+15.0 * u.deg, dec=-45.0 * u.deg, frame='icrs', equinox='J2000')
vt = create_visibility(lowcore, times, frequency, channel_bandwidth=channel_bandwidth,
                       weight=1.0, phasecentre=phasecentre, 
                       polarisation_frame=PolarisationFrame('stokesI'))
# Out:
# create_visibility: 95865 rows, 0.010 GB

# %%
advice = advise_wide_field(vt, wprojection_planes=1)
# Out:
# advise_wide_field: Maximum wavelength 2.998 (meters)
# advise_wide_field: Minimum wavelength 2.998 (meters)
# advise_wide_field: Maximum baseline 262.6 (wavelengths)
# advise_wide_field: Station/antenna diameter 35.0 (meters)
# advise_wide_field: Primary beam 0.085655 (rad) 4.908 (deg)
# advise_wide_field: Image field of view 0.513930 (rad) 29.446 (deg)
# advise_wide_field: Synthesized beam 0.003808 (rad) 0.218 (deg)
# advise_wide_field: Cellsize 0.001269 (rad) 0.073 (deg)
# advice_wide_field: Npixels per side = 405
# advice_wide_field: Npixels (power of 2, 3) per side = 512
# advice_wide_field: W sampling for full image = 0.2 (wavelengths)
# advice_wide_field: W sampling for primary beam = 8.7 (wavelengths)
# advice_wide_field: Time sampling for full image = 25.2 (s)
# advice_wide_field: Time sampling for primary beam = 908.6 (s)
# advice_wide_field: Frequency sampling for full image = 29212.6 (Hz)
# advice_wide_field: Frequency sampling for primary beam = 1051653.8 (Hz)
# advice_wide_field: Number of planes in w stack 30
# advice_wide_field: Number of planes in w projection 1
# advice_wide_field: Recommend that 2d gridding (i.e. no wprojection) is used

# %% [markdown]
# Fill in the visibility with exact calculation of a number of point sources

# %%
vt.data['vis'] *= 0.0
npixel=256

model = create_image_from_visibility(vt, npixel=npixel, cellsize=0.001, nchan=1, 
                                     polarisation_frame=PolarisationFrame('stokesI'))
centre = model.wcs.wcs.crpix-1
spacing_pixels = npixel // 8
log.info('Spacing in pixels = %s' % spacing_pixels)
spacing = model.wcs.wcs.cdelt * spacing_pixels
locations = [-3.5, -2.5, -1.5, -0.5, 0.5, 1.5, 2.5, 3.5]

original_comps = []
# We calculate the source positions in pixels and then calculate the
# world coordinates to put in the skycomponent description
for iy in locations:
    for ix in locations:
        if ix >= iy:
            p = int(round(centre[0] + ix * spacing_pixels * numpy.sign(model.wcs.wcs.cdelt[0]))), \
                int(round(centre[1] + iy * spacing_pixels * numpy.sign(model.wcs.wcs.cdelt[1])))
            sc = pixel_to_skycoord(p[0], p[1], model.wcs)
            log.info("Component at (%f, %f) [0-rel] %s" % (p[0], p[1], str(sc)))
            flux = numpy.array([[100.0 + 2.0 * ix + iy * 20.0]])
            comp = create_skycomponent(flux=flux, frequency=frequency, direction=sc, 
                                       polarisation_frame=PolarisationFrame('stokesI'))
            original_comps.append(comp)
            insert_skycomponent(model, comp)

predict_skycomponent_visibility(vt, original_comps)

        
cmodel = smooth_image(model) 
show_image(cmodel)
plt.title("Smoothed model image")
plt.show()
# Out:
# create_image_from_visibility: Parsing parameters to get definition of WCS
# create_image_from_visibility: Defining single channel Image at <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>, starting frequency 100000000.0 Hz, and bandwidth 999999.99999 Hz
# create_image_from_visibility: uvmax = 262.634709 wavelengths
# create_image_from_visibility: Critical cellsize = 0.001904 radians, 0.109079 degrees
# create_image_from_visibility: Cellsize          = 0.001000 radians, 0.057296 degrees
# Spacing in pixels = 32
# Component at (240.000000, 16.000000) [0-rel] <SkyCoord (ICRS): (ra, dec) in deg
#     (4.74378292, -51.0209895)>
# insert_skycomponent: Using insert method Nearest
# Component at (208.000000, 16.000000) [0-rel] <SkyCoord (ICRS): (ra, dec) in deg
#     (7.66144755, -51.22149637)>
# insert_skycomponent: Using insert method Nearest
# Component at (176.000000, 16.000000) [0-rel] <SkyCoord (ICRS): (ra, dec) in deg
#     (10.5917361, -51.35530369)>
# insert_skycomponent: Using insert method Nearest
# Component at (144.000000, 16.000000) [0-rel] <SkyCoord (ICRS): (ra, dec) in deg
#     (13.52971731, -51.42224945)>
# insert_skycomponent: Using insert method Nearest
# Component at (112.000000, 16.000000) [0-rel] <SkyCoord (ICRS): (ra, dec) in deg
#     (16.47028269, -51.42224945)>
# insert_skycomponent: Using insert method Nearest
# Component at (80.000000, 16.000000) [0-rel] <SkyCoord (ICRS): (ra, dec) in deg
#     (19.4082639, -51.35530369)>
# insert_skycomponent: Using insert method Nearest
# Component at (48.000000, 16.000000) [0-rel] <SkyCoord (ICRS): (ra, dec) in deg
#     (22.33855245, -51.22149637)>
# insert_skycomponent: Using insert method Nearest
# Component at (16.000000, 16.000000) [0-rel] <SkyCoord (ICRS): (ra, dec) in deg
#     (25.25621708, -51.0209895)>
# insert_skycomponent: Using insert method Nearest
# Component at (208.000000, 48.000000) [0-rel] <SkyCoord (ICRS): (ra, dec) in deg
#     (7.94046978, -49.38802398)>
# insert_skycomponent: Using insert method Nearest
# Component at (176.000000, 48.000000) [0-rel] <SkyCoord (ICRS): (ra, dec) in deg
#     (10.76004686, -49.51635065)>
# insert_skycomponent: Using insert method Nearest
# Component at (144.000000, 48.000000) [0-rel] <SkyCoord (ICRS): (ra, dec) in deg
#     (13.58597172, -49.5805407)>
# insert_skycomponent: Using insert method Nearest
# Component at (112.000000, 48.000000) [0-rel] <SkyCoord (ICRS): (ra, dec) in deg
#     (16.41402828, -49.5805407)>
# insert_skycomponent: Using insert method Nearest
# Component at (80.000000, 48.000000) [0-rel] <SkyCoord (ICRS): (ra, dec) in deg
#     (19.23995314, -49.51635065)>
# insert_skycomponent: Using insert method Nearest
# Component at (48.000000, 48.000000) [0-rel] <SkyCoord (ICRS): (ra, dec) in deg
#     (22.05953022, -49.38802398)>
# insert_skycomponent: Using insert method Nearest
# Component at (16.000000, 48.000000) [0-rel] <SkyCoord (ICRS): (ra, dec) in deg
#     (24.86868384, -49.19566221)>
# insert_skycomponent: Using insert method Nearest
# Component at (176.000000, 80.000000) [0-rel] <SkyCoord (ICRS): (ra, dec) in deg
#     (10.91156133, -47.68176393)>
# insert_skycomponent: Using insert method Nearest
# Component at (144.000000, 80.000000) [0-rel] <SkyCoord (ICRS): (ra, dec) in deg
#     (13.63659973, -47.74353279)>
# insert_skycomponent: Using insert method Nearest
# Component at (112.000000, 80.000000) [0-rel] <SkyCoord (ICRS): (ra, dec) in deg
#     (16.36340027, -47.74353279)>
# insert_skycomponent: Using insert method Nearest
# Component at (80.000000, 80.000000) [0-rel] <SkyCoord (ICRS): (ra, dec) in deg
#     (19.08843867, -47.68176393)>
# insert_skycomponent: Using insert method Nearest
# Component at (48.000000, 80.000000) [0-rel] <SkyCoord (ICRS): (ra, dec) in deg
#     (21.80822877, -47.55825467)>
# insert_skycomponent: Using insert method Nearest
# Component at (16.000000, 80.000000) [0-rel] <SkyCoord (ICRS): (ra, dec) in deg
#     (24.51939763, -47.3730574)>
# insert_skycomponent: Using insert method Nearest
# Component at (144.000000, 112.000000) [0-rel] <SkyCoord (ICRS): (ra, dec) in deg
#     (13.68235336, -45.90931658)>
# insert_skycomponent: Using insert method Nearest
# Component at (112.000000, 112.000000) [0-rel] <SkyCoord (ICRS): (ra, dec) in deg
#     (16.31764664, -45.90931658)>
# insert_skycomponent: Using insert method Nearest
# Component at (80.000000, 112.000000) [0-rel] <SkyCoord (ICRS): (ra, dec) in deg
#     (18.95148298, -45.84967813)>
# insert_skycomponent: Using insert method Nearest
# Component at (48.000000, 112.000000) [0-rel] <SkyCoord (ICRS): (ra, dec) in deg
#     (21.58097973, -45.73040913)>
# insert_skycomponent: Using insert method Nearest
# Component at (16.000000, 112.000000) [0-rel] <SkyCoord (ICRS): (ra, dec) in deg
#     (24.20334715, -45.55152143)>
# insert_skycomponent: Using insert method Nearest
# Component at (112.000000, 144.000000) [0-rel] <SkyCoord (ICRS): (ra, dec) in deg
#     (16.27614945, -44.07600819)>
# insert_skycomponent: Using insert method Nearest
# Component at (80.000000, 144.000000) [0-rel] <SkyCoord (ICRS): (ra, dec) in deg
#     (18.82724608, -44.01824481)>
# insert_skycomponent: Using insert method Nearest
# Component at (48.000000, 144.000000) [0-rel] <SkyCoord (ICRS): (ra, dec) in deg
#     (21.37476195, -43.90270873)>
# insert_skycomponent: Using insert method Nearest
# Component at (16.000000, 144.000000) [0-rel] <SkyCoord (ICRS): (ra, dec) in deg
#     (23.91639614, -43.72937783)>
# insert_skycomponent: Using insert method Nearest
# Component at (80.000000, 176.000000) [0-rel] <SkyCoord (ICRS): (ra, dec) in deg
#     (18.71420256, -42.18561677)>
# insert_skycomponent: Using insert method Nearest
# Component at (48.000000, 176.000000) [0-rel] <SkyCoord (ICRS): (ra, dec) in deg
#     (21.18706763, -42.07336315)>
# insert_skycomponent: Using insert method Nearest
# Component at (16.000000, 176.000000) [0-rel] <SkyCoord (ICRS): (ra, dec) in deg
#     (23.65510465, -41.90491964)>
# insert_skycomponent: Using insert method Nearest
# Component at (48.000000, 208.000000) [0-rel] <SkyCoord (ICRS): (ra, dec) in deg
#     (21.01580068, -40.24055692)>
# insert_skycomponent: Using insert method Nearest
# Component at (16.000000, 208.000000) [0-rel] <SkyCoord (ICRS): (ra, dec) in deg
#     (23.41659285, -40.07639948)>
# insert_skycomponent: Using insert method Nearest
# Component at (16.000000, 240.000000) [0-rel] <SkyCoord (ICRS): (ra, dec) in deg
#     (23.19843619, -38.24201755)>
# insert_skycomponent: Using insert method Nearest

# %% [markdown]
# Check that the skycoordinate and image coordinate system are consistent by finding the point sources.

# %%
comps = find_skycomponents(cmodel, fwhm=1.0, threshold=10.0, npixels=5)
plt.clf()
for i in range(len(comps)):
    ocomp = find_nearest_component(comps[i].direction, original_comps)
    plt.plot((comps[i].direction.ra.value  - ocomp.direction.ra.value)/cmodel.wcs.wcs.cdelt[0], 
             (comps[i].direction.dec.value - ocomp.direction.dec.value)/cmodel.wcs.wcs.cdelt[1], 
             '.', color='r')  

plt.xlabel('delta RA (pixels)')
plt.ylabel('delta DEC (pixels)')
plt.title("Recovered - Original position offsets")
plt.show()
# Out:
# find_skycomponents: Finding components in Image by segmentation
# find_skycomponents: Identified 36 segments

# %% [markdown]
# Predict the visibility using the different approaches.

# %%
from arl.imaging.imaging_context import imaging_contexts, predict_function, invert_function
contexts = ['2d', 'facets', 'timeslice', 'wstack', 'wprojection']


for context in contexts:

    print('Processing context %s' % context)
    if context == 'slice' or context == 'facets+slice':
        vis_slices = 10000
    else:
        vis_slices = 31

    if context == 'wprojection':
        acontext = '2d'
        kernel = 'wprojection'
    else:
        acontext = context
        kernel = '2d'

    uvdist = numpy.sqrt(vt.data['uvw'][:, 0]**2 + vt.data['uvw'][:, 1]**2)
    plt.clf()
    plt.plot(uvdist, numpy.abs(vt.data['vis'][:]), '.', color='r', label="DFT")
    vtpredict = create_visibility(
        lowcore,
        times,
        frequency,
        channel_bandwidth=channel_bandwidth,
        weight=1.0,
        phasecentre=phasecentre,
        polarisation_frame=PolarisationFrame('stokesI'))
    
    if context=='wprojection':
        wstep = advice['w_sampling_primary_beam']
    else:
        wstep=0.0
        
    set_parameters('imaging-fits.ini',
                   {'timeslice':'auto',
                    'vis_slices':vis_slices,
                    'wstack':advice['w_sampling_primary_beam'],
                    'oversampling':1,
                    'facets':8,
                    'wstep':wstep},
                   'imaging')
    
    vtpredict = predict_function(
        vtpredict,
        model,
        context=acontext,
        arl_config='imaging-fits.ini')

    plt.plot(
        uvdist,
        numpy.abs(vtpredict.data['vis'][:]),
        '.',
        color='b',
        label=context)
    plt.plot(
        uvdist,
        numpy.abs(vtpredict.data['vis'][:] - vt.data['vis'][:]),
        '.',
        color='g',
        label="Residual")
    plt.xlabel('uvdist')
    plt.ylabel('Amp Visibility')
    plt.legend()
    plt.show()
# Out:
# Processing context 2d
# create_visibility: 95865 rows, 0.010 GB
# Processing context facets
# create_visibility: 95865 rows, 0.010 GB
# raster: predicting using 8 x 8 image partitions
# raster: spacing of raster (32, 32)
# raster: partition (0, 0) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (25.25621708, -51.0209895)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (1, 0) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (22.33855245, -51.22149637)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (2, 0) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (19.4082639, -51.35530369)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (3, 0) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (16.47028269, -51.42224945)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (4, 0) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (13.52971731, -51.42224945)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (5, 0) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (10.5917361, -51.35530369)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (6, 0) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (7.66144755, -51.22149637)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (7, 0) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (4.74378292, -51.0209895)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (0, 1) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (24.86868384, -49.19566221)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (1, 1) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (22.05953022, -49.38802398)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (2, 1) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (19.23995314, -49.51635065)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (3, 1) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (16.41402828, -49.5805407)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (4, 1) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (13.58597172, -49.5805407)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (5, 1) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (10.76004686, -49.51635065)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (6, 1) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (7.94046978, -49.38802398)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (7, 1) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (5.13131616, -49.19566221)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (0, 2) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (24.51939763, -47.3730574)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (1, 2) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (21.80822877, -47.55825467)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (2, 2) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (19.08843867, -47.68176393)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (3, 2) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (16.36340027, -47.74353279)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (4, 2) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (13.63659973, -47.74353279)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (5, 2) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (10.91156133, -47.68176393)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (6, 2) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (8.19177123, -47.55825467)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (7, 2) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (5.48060237, -47.3730574)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (0, 3) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (24.20334715, -45.55152143)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (1, 3) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (21.58097973, -45.73040913)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (2, 3) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (18.95148298, -45.84967813)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (3, 3) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (16.31764664, -45.90931658)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (4, 3) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (13.68235336, -45.90931658)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (5, 3) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (11.04851702, -45.84967813)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (6, 3) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (8.41902027, -45.73040913)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (7, 3) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (5.79665285, -45.55152143)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (0, 4) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (23.91639614, -43.72937783)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (1, 4) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (21.37476195, -43.90270873)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (2, 4) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (18.82724608, -44.01824481)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (3, 4) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (16.27614945, -44.07600819)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (4, 4) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (13.72385055, -44.07600819)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (5, 4) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (11.17275392, -44.01824481)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (6, 4) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (8.62523805, -43.90270873)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (7, 4) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (6.08360386, -43.72937783)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (0, 5) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (23.65510465, -41.90491964)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (1, 5) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (21.18706763, -42.07336315)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (2, 5) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (18.71420256, -42.18561677)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (3, 5) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (16.23839672, -42.2417316)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (4, 5) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (13.76160328, -42.2417316)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (5, 5) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (11.28579744, -42.18561677)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (6, 5) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (8.81293237, -42.07336315)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (7, 5) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (6.34489535, -41.90491964)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (0, 6) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (23.41659285, -40.07639948)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (1, 6) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (21.01580068, -40.24055692)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (2, 6) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (18.61107883, -40.34993216)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (3, 6) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (16.20396125, -40.40460145)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (4, 6) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (13.79603875, -40.40460145)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (5, 6) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (11.38892117, -40.34993216)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (6, 6) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (8.98419932, -40.24055692)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (7, 6) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (6.58340715, -40.07639948)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (0, 7) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (23.19843619, -38.24201755)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (1, 7) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (20.85919882, -38.40243471)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (2, 7) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (18.51680511, -38.50929785)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (3, 7) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (16.17248434, -38.56270547)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (4, 7) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (13.82751566, -38.56270547)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (5, 7) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (11.48319489, -38.50929785)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (6, 7) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (9.14080118, -38.40243471)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# raster: partition (7, 7) of (8, 8)
# shift_vis_from_image: shifting phasecentre from image phase centre <SkyCoord (ICRS): (ra, dec) in deg
#     (6.80156381, -38.24201755)> to visibility phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>
# Processing context timeslice
# create_visibility: 95865 rows, 0.010 GB
# predict_timeslice: predicting using time slices
# fit_uvwplane: Fit to 13695 rows reduces rms w from 59.6 to 0.0 m
# predict_timeslice: predicting using time slices
# fit_uvwplane: Fit to 13695 rows reduces rms w from 46.1 to 0.0 m
# predict_timeslice: predicting using time slices
# fit_uvwplane: Fit to 13695 rows reduces rms w from 33.7 to 0.0 m
# predict_timeslice: predicting using time slices
# fit_uvwplane: Fit to 13695 rows reduces rms w from 28.0 to 0.0 m
# predict_timeslice: predicting using time slices
# fit_uvwplane: Fit to 13695 rows reduces rms w from 33.8 to 0.0 m
# predict_timeslice: predicting using time slices
# fit_uvwplane: Fit to 13695 rows reduces rms w from 46.2 to 0.0 m
# predict_timeslice: predicting using time slices
# fit_uvwplane: Fit to 13695 rows reduces rms w from 59.7 to 0.0 m
# Processing context wstack
# create_visibility: 95865 rows, 0.010 GB
# predict_wstack_single: predicting using single w slice
# create_w_term_image: For w = -158.7, field of view = 0.256000, Fresnel number = 2.60
# predict_wstack_single: predicting using single w slice
# create_w_term_image: For w = -151.5, field of view = 0.256000, Fresnel number = 2.48
# predict_wstack_single: predicting using single w slice
# create_w_term_image: For w = -143.4, field of view = 0.256000, Fresnel number = 2.35
# predict_wstack_single: predicting using single w slice
# create_w_term_image: For w = -135.5, field of view = 0.256000, Fresnel number = 2.22
# predict_wstack_single: predicting using single w slice
# create_w_term_image: For w = -127.1, field of view = 0.256000, Fresnel number = 2.08
# predict_wstack_single: predicting using single w slice
# create_w_term_image: For w = -118.3, field of view = 0.256000, Fresnel number = 1.94
# predict_wstack_single: predicting using single w slice
# create_w_term_image: For w = -109.9, field of view = 0.256000, Fresnel number = 1.80
# predict_wstack_single: predicting using single w slice
# create_w_term_image: For w = -101.7, field of view = 0.256000, Fresnel number = 1.67
# predict_wstack_single: predicting using single w slice
# create_w_term_image: For w = -93.1, field of view = 0.256000, Fresnel number = 1.53
# predict_wstack_single: predicting using single w slice
# create_w_term_image: For w = -84.6, field of view = 0.256000, Fresnel number = 1.39
# predict_wstack_single: predicting using single w slice
# create_w_term_image: For w = -76.1, field of view = 0.256000, Fresnel number = 1.25
# predict_wstack_single: predicting using single w slice
# create_w_term_image: For w = -67.6, field of view = 0.256000, Fresnel number = 1.11
# predict_wstack_single: predicting using single w slice
# create_w_term_image: For w = -59.1, field of view = 0.256000, Fresnel number = 0.97
# predict_wstack_single: predicting using single w slice
# create_w_term_image: For w = -50.7, field of view = 0.256000, Fresnel number = 0.83
# predict_wstack_single: predicting using single w slice
# create_w_term_image: For w = -42.3, field of view = 0.256000, Fresnel number = 0.69
# predict_wstack_single: predicting using single w slice
# create_w_term_image: For w = -33.8, field of view = 0.256000, Fresnel number = 0.55
# predict_wstack_single: predicting using single w slice
# create_w_term_image: For w = -25.4, field of view = 0.256000, Fresnel number = 0.42
# predict_wstack_single: predicting using single w slice
# create_w_term_image: For w = -16.9, field of view = 0.256000, Fresnel number = 0.28
# predict_wstack_single: predicting using single w slice
# create_w_term_image: For w = -8.5, field of view = 0.256000, Fresnel number = 0.14
# predict_wstack_single: predicting using single w slice
# create_w_term_image: For w = -0.0, field of view = 0.256000, Fresnel number = 0.00
# predict_wstack_single: predicting using single w slice
# create_w_term_image: For w = 8.4, field of view = 0.256000, Fresnel number = 0.14
# predict_wstack_single: predicting using single w slice
# create_w_term_image: For w = 16.9, field of view = 0.256000, Fresnel number = 0.28
# predict_wstack_single: predicting using single w slice
# create_w_term_image: For w = 25.3, field of view = 0.256000, Fresnel number = 0.42
# predict_wstack_single: predicting using single w slice
# create_w_term_image: For w = 33.8, field of view = 0.256000, Fresnel number = 0.55
# predict_wstack_single: predicting using single w slice
# create_w_term_image: For w = 42.2, field of view = 0.256000, Fresnel number = 0.69
# predict_wstack_single: predicting using single w slice
# create_w_term_image: For w = 50.8, field of view = 0.256000, Fresnel number = 0.83
# predict_wstack_single: predicting using single w slice
# create_w_term_image: For w = 59.2, field of view = 0.256000, Fresnel number = 0.97
# predict_wstack_single: predicting using single w slice
# create_w_term_image: For w = 67.7, field of view = 0.256000, Fresnel number = 1.11
# predict_wstack_single: predicting using single w slice
# create_w_term_image: For w = 76.1, field of view = 0.256000, Fresnel number = 1.25
# predict_wstack_single: predicting using single w slice
# create_w_term_image: For w = 84.6, field of view = 0.256000, Fresnel number = 1.39
# predict_wstack_single: predicting using single w slice
# create_w_term_image: For w = 93.0, field of view = 0.256000, Fresnel number = 1.52
# predict_wstack_single: predicting using single w slice
# create_w_term_image: For w = 101.5, field of view = 0.256000, Fresnel number = 1.66
# predict_wstack_single: predicting using single w slice
# create_w_term_image: For w = 110.0, field of view = 0.256000, Fresnel number = 1.80
# predict_wstack_single: predicting using single w slice
# create_w_term_image: For w = 118.3, field of view = 0.256000, Fresnel number = 1.94
# predict_wstack_single: predicting using single w slice
# create_w_term_image: For w = 126.8, field of view = 0.256000, Fresnel number = 2.08
# predict_wstack_single: predicting using single w slice
# create_w_term_image: For w = 135.3, field of view = 0.256000, Fresnel number = 2.22
# predict_wstack_single: predicting using single w slice
# create_w_term_image: For w = 143.9, field of view = 0.256000, Fresnel number = 2.36
# predict_wstack_single: predicting using single w slice
# create_w_term_image: For w = 152.0, field of view = 0.256000, Fresnel number = 2.49
# predict_wstack_single: predicting using single w slice
# create_w_term_image: For w = 159.1, field of view = 0.256000, Fresnel number = 2.61
# predict_wstack_single: predicting using single w slice
# create_w_term_image: For w = 167.9, field of view = 0.256000, Fresnel number = 2.75
# Processing context wprojection
# create_visibility: 95865 rows, 0.010 GB
# get_kernel_list: Using wprojection kernel
# get_kernel_list: Fresnel number = 16.384000
# advise_wide_field: Maximum wavelength 2.998 (meters)
# advise_wide_field: Minimum wavelength 2.998 (meters)
# advise_wide_field: Maximum baseline 262.6 (wavelengths)
# advise_wide_field: Station/antenna diameter 35.0 (meters)
# advise_wide_field: Primary beam 0.085655 (rad) 4.908 (deg)
# advise_wide_field: Image field of view 0.513930 (rad) 29.446 (deg)
# advise_wide_field: Synthesized beam 0.003808 (rad) 0.218 (deg)
# advise_wide_field: Cellsize 0.001269 (rad) 0.073 (deg)
# advice_wide_field: Npixels per side = 405
# advice_wide_field: Npixels (power of 2, 3) per side = 512
# advice_wide_field: W sampling for full image = 0.2 (wavelengths)
# advice_wide_field: W sampling for primary beam = 8.7 (wavelengths)
# advice_wide_field: Time sampling for full image = 25.2 (s)
# advice_wide_field: Time sampling for primary beam = 908.6 (s)
# advice_wide_field: Frequency sampling for full image = 29212.6 (Hz)
# advice_wide_field: Frequency sampling for primary beam = 1051653.8 (Hz)
# advice_wide_field: Number of planes in w stack 30
# advice_wide_field: Number of planes in w projection 1
# advice_wide_field: Recommend that 2d gridding (i.e. no wprojection) is used
# get_kernel_list: Using w projection with wstep = 8.677104
# get_kernel_list: Maximum w kernel full width = 22 pixels
# w_kernel_list: Maximum absolute w = 169.6, step is 8.7 wavelengths
# create_w_term_image: For w = -169.6, field of view = 0.512000, Fresnel number = 11.12
# create_w_term_image: For w = -161.2, field of view = 0.512000, Fresnel number = 10.56
# create_w_term_image: For w = -152.7, field of view = 0.512000, Fresnel number = 10.01
# create_w_term_image: For w = -144.2, field of view = 0.512000, Fresnel number = 9.45
# create_w_term_image: For w = -135.7, field of view = 0.512000, Fresnel number = 8.89
# create_w_term_image: For w = -127.2, field of view = 0.512000, Fresnel number = 8.34
# create_w_term_image: For w = -118.8, field of view = 0.512000, Fresnel number = 7.78
# create_w_term_image: For w = -110.3, field of view = 0.512000, Fresnel number = 7.23
# create_w_term_image: For w = -101.8, field of view = 0.512000, Fresnel number = 6.67
# create_w_term_image: For w = -93.3, field of view = 0.512000, Fresnel number = 6.11
# create_w_term_image: For w = -84.8, field of view = 0.512000, Fresnel number = 5.56
# create_w_term_image: For w = -76.3, field of view = 0.512000, Fresnel number = 5.00
# create_w_term_image: For w = -67.9, field of view = 0.512000, Fresnel number = 4.45
# create_w_term_image: For w = -59.4, field of view = 0.512000, Fresnel number = 3.89
# create_w_term_image: For w = -50.9, field of view = 0.512000, Fresnel number = 3.34
# create_w_term_image: For w = -42.4, field of view = 0.512000, Fresnel number = 2.78
# create_w_term_image: For w = -33.9, field of view = 0.512000, Fresnel number = 2.22
# create_w_term_image: For w = -25.4, field of view = 0.512000, Fresnel number = 1.67
# create_w_term_image: For w = -17.0, field of view = 0.512000, Fresnel number = 1.11
# create_w_term_image: For w = -8.5, field of view = 0.512000, Fresnel number = 0.56
# create_w_term_image: For w = -0.0, field of view = 0.512000, Fresnel number = 0.00
# create_w_term_image: For w = 8.5, field of view = 0.512000, Fresnel number = 0.56
# create_w_term_image: For w = 17.0, field of view = 0.512000, Fresnel number = 1.11
# create_w_term_image: For w = 25.4, field of view = 0.512000, Fresnel number = 1.67
# create_w_term_image: For w = 33.9, field of view = 0.512000, Fresnel number = 2.22
# create_w_term_image: For w = 42.4, field of view = 0.512000, Fresnel number = 2.78
# create_w_term_image: For w = 50.9, field of view = 0.512000, Fresnel number = 3.34
# create_w_term_image: For w = 59.4, field of view = 0.512000, Fresnel number = 3.89
# create_w_term_image: For w = 67.9, field of view = 0.512000, Fresnel number = 4.45
# create_w_term_image: For w = 76.3, field of view = 0.512000, Fresnel number = 5.00
# create_w_term_image: For w = 84.8, field of view = 0.512000, Fresnel number = 5.56
# create_w_term_image: For w = 93.3, field of view = 0.512000, Fresnel number = 6.11
# create_w_term_image: For w = 101.8, field of view = 0.512000, Fresnel number = 6.67
# create_w_term_image: For w = 110.3, field of view = 0.512000, Fresnel number = 7.23
# create_w_term_image: For w = 118.8, field of view = 0.512000, Fresnel number = 7.78
# create_w_term_image: For w = 127.2, field of view = 0.512000, Fresnel number = 8.34
# create_w_term_image: For w = 135.7, field of view = 0.512000, Fresnel number = 8.89
# create_w_term_image: For w = 144.2, field of view = 0.512000, Fresnel number = 9.45
# create_w_term_image: For w = 152.7, field of view = 0.512000, Fresnel number = 10.01
# create_w_term_image: For w = 161.2, field of view = 0.512000, Fresnel number = 10.56
# create_w_term_image: For w = 169.6, field of view = 0.512000, Fresnel number = 11.12

# %% [markdown]
# Make the image using the different approaches. We will evaluate the results using a number of plots:
#
# - The error in fitted versus the radius. The ideal result is a straightline fitted: flux = DFT flux
# - The offset in RA versus the offset in DEC. The ideal result is a cluster around 0 pixels.
#
# The sampling in w is set to provide 2% decorrelation at the half power point of the primary beam.

# %%
contexts = ['2d', 'facets', 'timeslice', 'wstack', 'wprojection']

for context in contexts:

    print('Processing context %s' % context)
    vis_slices = 31

    if context == 'wprojection':
        acontext = '2d'
        kernel = 'wprojection'
    else:
        acontext = context
        kernel = '2d'

    targetimage = create_image_from_visibility(
        vt,
        npixel=npixel,
        cellsize=0.001,
        nchan=1,
        polarisation_frame=PolarisationFrame('stokesI'))

        
    if context=='wprojection':
        wstep = advice['w_sampling_primary_beam']
    else:
        wstep=0.0
        
    set_parameters('imaging-fits.ini',
                   {'timeslice':'auto',
                    'vis_slices':vis_slices,
                    'oversampling':4,
                    'facets':8,
                    'wstep':wstep},
                   'imaging')

    targetimage, sumwt = invert_function(vt, targetimage, context=context, arl_config='imaging-fits.ini')

    show_image(targetimage)
    plt.title(context)
    plt.show()

    print("Dirty Image %s" % qa_image(
        targetimage,
        context="imaging-fits notebook, using processor %s" %
        context))

    export_image_to_fits(targetimage, '%s/imaging-fits_dirty_%s.fits' %
                         (results_dir, context))
    comps = find_skycomponents(
        targetimage, fwhm=1.0, threshold=10.0, npixels=5)

    plt.clf()
    for comp in comps:
        distance = comp.direction.separation(model.phasecentre)
        dft_flux = sum_visibility(vt, comp.direction)[0]
        err = (comp.flux[0, 0] - dft_flux) / dft_flux
        plt.plot(distance, err, '.', color='r')
    plt.ylabel('Fractional error of image vs DFT')
    plt.xlabel('Distance from phasecentre (deg)')
    plt.title(
        "Fractional error in %s recovered flux vs distance from phasecentre" %
        context)
    plt.show()

    checkpositions = True
    if checkpositions:
        plt.clf()
        for i in range(len(comps)):
            ocomp = find_nearest_component(comps[i].direction, original_comps)
            plt.plot(
                (comps[i].direction.ra.value - ocomp.direction.ra.value) /
                targetimage.wcs.wcs.cdelt[0],
                (comps[i].direction.dec.value - ocomp.direction.dec.value) /
                targetimage.wcs.wcs.cdelt[1],
                '.',
                color='r')

        plt.xlabel('delta RA (pixels)')
        plt.ylabel('delta DEC (pixels)')
        plt.title("%s: Position offsets" % context)
        plt.show()
# Out:
# Processing context 2d
# create_image_from_visibility: Parsing parameters to get definition of WCS
# create_image_from_visibility: Defining single channel Image at <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>, starting frequency 100000000.0 Hz, and bandwidth 999999.99999 Hz
# create_image_from_visibility: uvmax = 262.634709 wavelengths
# create_image_from_visibility: Critical cellsize = 0.001904 radians, 0.109079 degrees
# create_image_from_visibility: Cellsize          = 0.001000 radians, 0.057296 degrees
# Dirty Image Quality assessment:
# 	Origin: qa_image
# 	Context: imaging-fits notebook, using processor 2d
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 108.25327827800872
# 		min: -6.007007151172118
# 		rms: 4.9180685850909365
# 		sum: 3407.0661446796285
# 		medianabs: 1.1549448932934598
# 		median: -0.5835667245556522
#
# find_skycomponents: Finding components in Image by segmentation
# find_skycomponents: Identified 28 segments
# Processing context facets
# create_image_from_visibility: Parsing parameters to get definition of WCS
# create_image_from_visibility: Defining single channel Image at <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>, starting frequency 100000000.0 Hz, and bandwidth 999999.99999 Hz
# create_image_from_visibility: uvmax = 262.634709 wavelengths
# create_image_from_visibility: Critical cellsize = 0.001904 radians, 0.109079 degrees
# create_image_from_visibility: Cellsize          = 0.001000 radians, 0.057296 degrees
# raster: predicting using 8 x 8 image partitions
# raster: spacing of raster (32, 32)
# raster: partition (0, 0) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (25.25621708, -51.0209895)>
# raster: partition (1, 0) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (22.33855245, -51.22149637)>
# raster: partition (2, 0) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (19.4082639, -51.35530369)>
# raster: partition (3, 0) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (16.47028269, -51.42224945)>
# raster: partition (4, 0) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (13.52971731, -51.42224945)>
# raster: partition (5, 0) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (10.5917361, -51.35530369)>
# raster: partition (6, 0) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (7.66144755, -51.22149637)>
# raster: partition (7, 0) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (4.74378292, -51.0209895)>
# raster: partition (0, 1) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (24.86868384, -49.19566221)>
# raster: partition (1, 1) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (22.05953022, -49.38802398)>
# raster: partition (2, 1) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (19.23995314, -49.51635065)>
# raster: partition (3, 1) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (16.41402828, -49.5805407)>
# raster: partition (4, 1) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (13.58597172, -49.5805407)>
# raster: partition (5, 1) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (10.76004686, -49.51635065)>
# raster: partition (6, 1) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (7.94046978, -49.38802398)>
# raster: partition (7, 1) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (5.13131616, -49.19566221)>
# raster: partition (0, 2) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (24.51939763, -47.3730574)>
# raster: partition (1, 2) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (21.80822877, -47.55825467)>
# raster: partition (2, 2) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (19.08843867, -47.68176393)>
# raster: partition (3, 2) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (16.36340027, -47.74353279)>
# raster: partition (4, 2) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (13.63659973, -47.74353279)>
# raster: partition (5, 2) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (10.91156133, -47.68176393)>
# raster: partition (6, 2) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (8.19177123, -47.55825467)>
# raster: partition (7, 2) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (5.48060237, -47.3730574)>
# raster: partition (0, 3) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (24.20334715, -45.55152143)>
# raster: partition (1, 3) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (21.58097973, -45.73040913)>
# raster: partition (2, 3) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (18.95148298, -45.84967813)>
# raster: partition (3, 3) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (16.31764664, -45.90931658)>
# raster: partition (4, 3) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (13.68235336, -45.90931658)>
# raster: partition (5, 3) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (11.04851702, -45.84967813)>
# raster: partition (6, 3) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (8.41902027, -45.73040913)>
# raster: partition (7, 3) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (5.79665285, -45.55152143)>
# raster: partition (0, 4) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (23.91639614, -43.72937783)>
# raster: partition (1, 4) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (21.37476195, -43.90270873)>
# raster: partition (2, 4) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (18.82724608, -44.01824481)>
# raster: partition (3, 4) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (16.27614945, -44.07600819)>
# raster: partition (4, 4) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (13.72385055, -44.07600819)>
# raster: partition (5, 4) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (11.17275392, -44.01824481)>
# raster: partition (6, 4) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (8.62523805, -43.90270873)>
# raster: partition (7, 4) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (6.08360386, -43.72937783)>
# raster: partition (0, 5) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (23.65510465, -41.90491964)>
# raster: partition (1, 5) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (21.18706763, -42.07336315)>
# raster: partition (2, 5) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (18.71420256, -42.18561677)>
# raster: partition (3, 5) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (16.23839672, -42.2417316)>
# raster: partition (4, 5) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (13.76160328, -42.2417316)>
# raster: partition (5, 5) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (11.28579744, -42.18561677)>
# raster: partition (6, 5) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (8.81293237, -42.07336315)>
# raster: partition (7, 5) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (6.34489535, -41.90491964)>
# raster: partition (0, 6) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (23.41659285, -40.07639948)>
# raster: partition (1, 6) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (21.01580068, -40.24055692)>
# raster: partition (2, 6) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (18.61107883, -40.34993216)>
# raster: partition (3, 6) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (16.20396125, -40.40460145)>
# raster: partition (4, 6) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (13.79603875, -40.40460145)>
# raster: partition (5, 6) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (11.38892117, -40.34993216)>
# raster: partition (6, 6) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (8.98419932, -40.24055692)>
# raster: partition (7, 6) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (6.58340715, -40.07639948)>
# raster: partition (0, 7) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (23.19843619, -38.24201755)>
# raster: partition (1, 7) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (20.85919882, -38.40243471)>
# raster: partition (2, 7) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (18.51680511, -38.50929785)>
# raster: partition (3, 7) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (16.17248434, -38.56270547)>
# raster: partition (4, 7) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (13.82751566, -38.56270547)>
# raster: partition (5, 7) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (11.48319489, -38.50929785)>
# raster: partition (6, 7) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (9.14080118, -38.40243471)>
# raster: partition (7, 7) of (8, 8)
# shift_vis_from_image: shifting phasecentre from vis phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)> to image phasecentre <SkyCoord (ICRS): (ra, dec) in deg
#     (6.80156381, -38.24201755)>
# Dirty Image Quality assessment:
# 	Origin: qa_image
# 	Context: imaging-fits notebook, using processor facets
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 176.74454992743028
# 		min: -6.343262561820508
# 		rms: 6.587885128801689
# 		sum: 3395.5582129368117
# 		medianabs: 1.1342945649740477
# 		median: -0.655515140599304
#
# find_skycomponents: Finding components in Image by segmentation
# find_skycomponents: Identified 36 segments
# Processing context timeslice
# create_image_from_visibility: Parsing parameters to get definition of WCS
# create_image_from_visibility: Defining single channel Image at <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>, starting frequency 100000000.0 Hz, and bandwidth 999999.99999 Hz
# create_image_from_visibility: uvmax = 262.634709 wavelengths
# create_image_from_visibility: Critical cellsize = 0.001904 radians, 0.109079 degrees
# create_image_from_visibility: Cellsize          = 0.001000 radians, 0.057296 degrees
# invert_timeslice: inverting using time slices
# fit_uvwplane: Fit to 13695 rows reduces rms w from 59.6 to 0.0 m
# invert_timeslice: inverting using time slices
# fit_uvwplane: Fit to 13695 rows reduces rms w from 46.1 to 0.0 m
# invert_timeslice: inverting using time slices
# fit_uvwplane: Fit to 13695 rows reduces rms w from 33.7 to 0.0 m
# invert_timeslice: inverting using time slices
# fit_uvwplane: Fit to 13695 rows reduces rms w from 28.0 to 0.0 m
# invert_timeslice: inverting using time slices
# fit_uvwplane: Fit to 13695 rows reduces rms w from 33.8 to 0.0 m
# invert_timeslice: inverting using time slices
# fit_uvwplane: Fit to 13695 rows reduces rms w from 46.2 to 0.0 m
# invert_timeslice: inverting using time slices
# fit_uvwplane: Fit to 13695 rows reduces rms w from 59.7 to 0.0 m
# Dirty Image Quality assessment:
# 	Origin: qa_image
# 	Context: imaging-fits notebook, using processor timeslice
# 	Data:
# 		shape: (1, 1, 256, 256)
# 		max: 167.14960955092022
# 		min: -6.082972194467366
# 		rms: 6.501412973366595
# 		sum: 4187.449124620528
# 		medianabs: 1.1042943048739473
# 		median: -0.6276103968834278
#
# find_skycomponents: Finding components in Image by segmentation
# find_skycomponents: Identified 36 segments
# Processing context wstack
# create_image_from_visibility: Parsing parameters to get definition of WCS
# create_image_from_visibility: Defining single channel Image at <SkyCoord (ICRS): (ra, dec) in deg
#     (15., -45.)>, starting frequency 100000000.0 Hz, and bandwidth 999999.99999 Hz
# create_image_from_visibility: uvmax = 262.634709 wavelengths
# create_image_from_visibility: Critical cellsize = 0.001904 radians, 0.109079 degrees
# create_image_from_visibility: Cellsize          = 0.001000 radians, 0.057296 degrees
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-15-f7ccdfff316f> in <module>()
#      34                    'imaging')
#      35
# ---> 36     targetimage, sumwt = invert_function(vt, targetimage, context=context, arl_config='imaging-fits.ini')
#      37
#      38     show_image(targetimage)
#
# ~/Code/algorithm-reference-library/arl/imaging/imaging_context.py in invert_function(vis, im, dopsf, normalize, context, inner, arl_config)
#     187     if inner == 'image':
#     188         totalwt = None
# --> 189         for rows in make_vis_iter(vis, context, arl_config=arl_config):
#     190             if numpy.sum(rows):
#     191                 visslice = create_visibility_from_rows(svis, rows)
#
# ~/Code/algorithm-reference-library/arl/visibility/iterators.py in vis_wstack_iter(vis, wstack, vis_slices)
#      72
#      73     if wstack is None:
# ---> 74         assert vis_slices is not None, "w slicing not specified: set either wstack or vis_slices"
#      75         vis_slices = int(vis_slices)
#      76         boxes = numpy.linspace(-wmaxabs, wmaxabs, vis_slices)
#
# AssertionError: w slicing not specified: set either wstack or vis_slices
